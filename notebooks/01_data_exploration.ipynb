# %%
import pandas as pd
import numpy as np
import os

# %%
yield_df = pd.read_csv("yield.csv")
print(yield_df.shape)
# Out:
# (56717, 12)

# %%
yield_df_processed = pd.read_csv("yield_df.csv")
print("yield_df.csv", yield_df_processed.shape)
# Out:
# yield_df.csv (28242, 8)

# %%
print("yield.csv colums")
print(yield_df.columns.tolist())

print("\n")

print("yield_df.csv columns")
print(yield_df_processed.columns.tolist())
# Out:
# yield.csv colums
# ['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value']
#
#
# yield_df.csv columns
# ['Unnamed: 0', 'Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']

# %%
yield_df.head()
# Out:
#   Domain Code Domain  Area Code         Area  Element Code Element  Item Code  \
# 0          QC  Crops          2  Afghanistan          5419   Yield         56
# 1          QC  Crops          2  Afghanistan          5419   Yield         56
# 2          QC  Crops          2  Afghanistan          5419   Yield         56
# 3          QC  Crops          2  Afghanistan          5419   Yield         56
# 4          QC  Crops          2  Afghanistan          5419   Yield         56
#
#     Item  Year Code  Year   Unit  Value
# 0  Maize       1961  1961  hg/ha  14000
# 1  Maize       1962  1962  hg/ha  14000
# 2  Maize       1963  1963  hg/ha  14260
# 3  Maize       1964  1964  hg/ha  14257
# 4  Maize       1965  1965  hg/ha  14400

# %%
yield_df_processed.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
temperature_df = pd.read_csv("temp.csv")
print(temperature_df.shape)
# Out:
# (71311, 3)

# %%
rainfall_df = pd.read_csv("rainfall.csv")
print(rainfall_df.shape)
# Out:
# (6727, 3)

# %%
pesticides_df = pd.read_csv("pesticides.csv")
print(pesticides_df.shape)
# Out:
# (4349, 7)

# %%
print(temperature_df.columns.tolist())
# Out:
# ['year', 'country', 'avg_temp']

# %%
print(rainfall_df.columns.tolist())
# Out:
# [' Area', 'Year', 'average_rain_fall_mm_per_year']

# %%
print(pesticides_df.columns.tolist())
# Out:
# ['Domain', 'Area', 'Element', 'Item', 'Year', 'Unit', 'Value']

# %%
print(temperature_df.head())
# Out:
#    year        country  avg_temp
# 0  1849  Côte D'Ivoire     25.58
# 1  1850  Côte D'Ivoire     25.52
# 2  1851  Côte D'Ivoire     25.67
# 3  1852  Côte D'Ivoire       NaN
# 4  1853  Côte D'Ivoire       NaN

# %%
print(rainfall_df.head())
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327

# %%
print(pesticides_df.head())
# Out:
#            Domain     Area Element                Item  Year  \
# 0  Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1  Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2  Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3  Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4  Pesticides Use  Albania     Use  Pesticides (total)  1994
#
#                            Unit  Value
# 0  tonnes of active ingredients  121.0
# 1  tonnes of active ingredients  121.0
# 2  tonnes of active ingredients  121.0
# 3  tonnes of active ingredients  121.0
# 4  tonnes of active ingredients  201.0

# %%
faostat_df = pd.read_csv("faostat_crop_production.csv")
faostat_df.shape
# Out:
# (6074, 15)

# %%
print(faostat_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6074 entries, 0 to 6073
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       6074 non-null   object
#  1   Domain            6074 non-null   object
#  2   Area Code (M49)   6074 non-null   int64
#  3   Area              6074 non-null   object
#  4   Element Code      6074 non-null   int64
#  5   Element           6074 non-null   object
#  6   Item Code (CPC)   6074 non-null   float64
#  7   Item              6074 non-null   object
#  8   Year Code         6074 non-null   int64
#  9   Year              6074 non-null   int64
#  10  Unit              6074 non-null   object
#  11  Value             6074 non-null   float64
#  12  Flag              6074 non-null   object
#  13  Flag Description  6074 non-null   object
#  14  Note              0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 711.9+ KB
# ...

# %%
faostat_df.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code Element  Item Code (CPC)               Item  Year Code  Year  \
# 0          5412   Yield           1371.0  Almonds, in shell       2011  2011
# 1          5412   Yield           1371.0  Almonds, in shell       2012  2012
# 2          5412   Yield           1371.0  Almonds, in shell       2013  2013
# 3          5412   Yield           1371.0  Almonds, in shell       2014  2014
# 4          5412   Yield           1371.0  Almonds, in shell       2015  2015
#
#     Unit  Value Flag Flag Description  Note
# 0  kg/ha  608.7    A   Official value   NaN
# ...

# %%
usda_df = pd.read_csv("usda_crop_yield.csv")
usda_df.shape
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8896\1903702029.py:1: DtypeWarning: Columns (0,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   usda_df = pd.read_csv("usda_crop_yield.csv")
# (98937, 39)

# %%
usda_df.columns.tolist()
# Out:
# ['region_desc',
#  'load_time',
#  'asd_code',
#  'year',
#  'sector_desc',
#  'week_ending',
#  'asd_desc',
#  'country_code',
#  'domaincat_desc',
#  'congr_district_code',
#  'county_name',
#  'state_alpha',
#  'group_desc',
#  'end_code',
#  'domain_desc',
#  'county_ansi',
#  'statisticcat_desc',
#  'state_fips_code',
#  'CV (%)',
#  'county_code',
#  'class_desc',
#  'prodn_practice_desc',
#  'reference_period_desc',
#  'zip_5',
#  'source_desc',
#  'location_desc',
#  'util_practice_desc',
#  'agg_level_desc',
#  'short_desc',
#  'unit_desc',
#  'commodity_desc',
#  'Value',
#  'country_name',
#  'watershed_code',
#  'begin_code',
#  'watershed_desc',
#  'state_name',
#  'state_ansi',
#  'freq_desc']

# %%
usda_df.head()
# Out:
#   region_desc                load_time  asd_code  year sector_desc  \
# 0         NaN  2024-02-23 15:00:00.000      10.0  2019       CROPS
# 1         NaN  2024-02-23 15:00:00.000      10.0  2018       CROPS
# 2         NaN  2018-02-22 15:08:35.000      10.0  2017       CROPS
# 3         NaN  2017-02-23 15:00:08.000      10.0  2016       CROPS
# 4         NaN  2016-02-18 15:04:50.000      10.0  2015       CROPS
#
#    week_ending         asd_desc  country_code domaincat_desc  \
# 0          NaN  NORTHERN VALLEY          9000  NOT SPECIFIED
# 1          NaN  NORTHERN VALLEY          9000  NOT SPECIFIED
# 2          NaN  NORTHERN VALLEY          9000  NOT SPECIFIED
# 3          NaN  NORTHERN VALLEY          9000  NOT SPECIFIED
# 4          NaN  NORTHERN VALLEY          9000  NOT SPECIFIED
#
#    congr_district_code  ...  unit_desc commodity_desc  Value   country_name  \
# 0                  NaN  ...  BU / ACRE           CORN  166.5  UNITED STATES
# ...

# %%
yield_df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ MB

# %%
yield_df_processed.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# ...

# %%
yield_df_processed.isnull().sum()
# Out:
# Unnamed: 0                       0
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64
